# %% [markdown]
# # 2022 World Cup Stats in Python

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
from datetime import datetime

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Ciaran Lynch

# %% [markdown]
# ### Call my data Frame df_World_Cup based on csv file called - Squads

# %%
df_World_Cup = pd.read_csv('C:\\Users\\Ciaran Lynch\\Squads.csv', header=None)

# %% [markdown]
# ### Show my new dataFrame, make sure it has been loaded correctly

# %%
df_World_Cup
# Out:
#       0                1     2   3   4                   5           6   7   \
# 0    ARG  argentina (ARG)  1001   1  GK       Franco Armani  16/10/1986  36
# 1    ARG  argentina (ARG)  1002   2  DF          Juan Foyth  12/01/1998  24
# 2    ARG  argentina (ARG)  1003   3  DF  Nicolás Tagliafico  31/08/1992  30
# 3    ARG  argentina (ARG)  1004   4  DF     Gonzalo Montiel  01/01/1997  25
# 4    ARG  argentina (ARG)  1005   5  MF     Leandro Paredes  29/06/1994  28
# ..   ...              ...   ...  ..  ..                 ...         ...  ..
# 825  WAL      wales (WAL)  1826  22  MF        Sorba Thomas  25/01/1999  23
# 826  WAL      wales (WAL)  1827  23  MF        Dylan Levitt  17/11/2000  22
# 827  WAL      wales (WAL)  1828  24  DF         Ben Cabango  30/05/2000  22
# 828  WAL      wales (WAL)  1829  25  MF       Rubin Colwill  27/04/2002  20
# 829  WAL      wales (WAL)  1830  26  MF       Matthew Smith  22/11/1999  22
#
#      8   9                    10                           11         12
# 0    18   0          River Plate  Liga Professional Argentina  Argentina
# 1    16   0           Villarreal                      La Liga      Spain
# 2    42   0                 Lyon                      Ligue 1     France
# 3    18   0              Sevilla                      La Liga      Spain
# 4    46   4             Juventus                      Serie A      Italy
# ..   ..  ..                  ...                          ...        ...
# 825   6   0    Huddersfield Town                 Championship    England
# 826  13   0        Dundee United                  Premiership   Scotland
# 827   5   0         Swansea City                 Championship    England
# 828   7   1         Cardiff City                 Championship    England
# 829  19   0   Milton Keynes Dons                   League One    England
#
# [830 rows x 13 columns]

# %% [markdown]
# ### Data Cleaning Operations

# %%
Column_Header =  {
                    df_World_Cup.columns[0]:  'National_Team_ID',
                    df_World_Cup.columns[1]:  'National_Team',
                    df_World_Cup.columns[2]:  'Player_No',
                    df_World_Cup.columns[3]:  'Squad_No',
                    df_World_Cup.columns[4]:  'Position',
                    df_World_Cup.columns[5]:  'Player_Name',
                    df_World_Cup.columns[6]:  'Date_Of_Birth',
                    df_World_Cup.columns[7]:  'Age',
                    df_World_Cup.columns[8]:  'Caps',
                    df_World_Cup.columns[9]:  'Goals',
                    df_World_Cup.columns[10]:  'Current_Club',
                    df_World_Cup.columns[11]: 'Football_League',
                    df_World_Cup.columns[12]: 'FA'
                    
                  }


df_World_Cup.rename(columns = Column_Header, inplace = True) # adding a dictionary to place columns into the headers in Python

# %% [markdown]
# ### check all the colums are imported correctly

# %%
df_World_Cup.columns
# Out:
# Index(['National_Team_ID', 'National_Team', 'Player_No', 'Squad_No',
#        'Position', 'Player_Name', 'Date_Of_Birth', 'Age', 'Caps', 'Goals',
#        'Current_Club', 'Football_League', 'FA'],
#       dtype='object')

# %%
df_World_Cup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 830 entries, 0 to 829
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   National_Team_ID  830 non-null    object
#  1   National_Team     830 non-null    object
#  2   Player_No         830 non-null    int64
#  3   Squad_No          830 non-null    int64
#  4   Position          830 non-null    object
#  5   Player_Name       830 non-null    object
#  6   Date_Of_Birth     830 non-null    object
#  7   Age               830 non-null    int64
#  8   Caps              830 non-null    int64
#  9   Goals             830 non-null    int64
#  10  Current_Club      830 non-null    object
#  11  Football_League   830 non-null    object
#  12  FA                830 non-null    object
# dtypes: int64(5), object(8)
# memory usage: 84.4+ KB

# %%
df_World_Cup.shape
# Out:
# (830, 13)

# %%
df_World_Cup['Date_Of_Birth'] = pd.to_datetime(df_World_Cup.Date_Of_Birth, dayfirst = True)

# %%
df_World_Cup.dtypes
# Out:
# National_Team_ID            object
# National_Team               object
# Player_No                    int64
# Squad_No                     int64
# Position                    object
# Player_Name                 object
# Date_Of_Birth       datetime64[ns]
# Age                          int64
# Caps                         int64
# Goals                        int64
# Current_Club                object
# Football_League             object
# FA                          object
# dtype: object

# %% [markdown]
# ### drop any rows that have less than 4 values

# %%
df_World_Cup.dropna(thresh=4, axis=0)
# Out:
#     National_Team_ID    National_Team  Player_No  Squad_No Position  \
# 0                ARG  argentina (ARG)       1001         1       GK
# 1                ARG  argentina (ARG)       1002         2       DF
# 2                ARG  argentina (ARG)       1003         3       DF
# 3                ARG  argentina (ARG)       1004         4       DF
# 4                ARG  argentina (ARG)       1005         5       MF
# ..               ...              ...        ...       ...      ...
# 825              WAL      wales (WAL)       1826        22       MF
# 826              WAL      wales (WAL)       1827        23       MF
# 827              WAL      wales (WAL)       1828        24       DF
# 828              WAL      wales (WAL)       1829        25       MF
# 829              WAL      wales (WAL)       1830        26       MF
#
#             Player_Name Date_Of_Birth  Age  Caps  Goals         Current_Club  \
# 0         Franco Armani    1986-10-16   36    18      0          River Plate
# 1            Juan Foyth    1998-01-12   24    16      0           Villarreal
# 2    Nicolás Tagliafico    1992-08-31   30    42      0                 Lyon
# 3       Gonzalo Montiel    1997-01-01   25    18      0              Sevilla
# 4       Leandro Paredes    1994-06-29   28    46      4             Juventus
# ..                  ...           ...  ...   ...    ...                  ...
# 825        Sorba Thomas    1999-01-25   23     6      0    Huddersfield Town
# 826        Dylan Levitt    2000-11-17   22    13      0        Dundee United
# 827         Ben Cabango    2000-05-30   22     5      0         Swansea City
# 828       Rubin Colwill    2002-04-27   20     7      1         Cardiff City
# 829       Matthew Smith    1999-11-22   22    19      0   Milton Keynes Dons
#
#                  Football_League         FA
# 0    Liga Professional Argentina  Argentina
# 1                        La Liga      Spain
# 2                        Ligue 1     France
# 3                        La Liga      Spain
# 4                        Serie A      Italy
# ..                           ...        ...
# 825                 Championship    England
# 826                  Premiership   Scotland
# 827                 Championship    England
# 828                 Championship    England
# 829                   League One    England
#
# [830 rows x 13 columns]

# %% [markdown]
# ### check rows are running in sequence, should be 830 rows with no blanks

# %%
df_World_Cup.index
# Out:
# RangeIndex(start=0, stop=830, step=1)

# %% [markdown]
# ## #quick look to see how the DataFrame is set

# %%
df_World_Cup.head(10)
# Out:
#   National_Team_ID    National_Team  Player_No  Squad_No Position  \
# 0              ARG  argentina (ARG)       1001         1       GK
# 1              ARG  argentina (ARG)       1002         2       DF
# 2              ARG  argentina (ARG)       1003         3       DF
# 3              ARG  argentina (ARG)       1004         4       DF
# 4              ARG  argentina (ARG)       1005         5       MF
# 5              ARG  argentina (ARG)       1006         6       DF
# 6              ARG  argentina (ARG)       1007         7       MF
# 7              ARG  argentina (ARG)       1008         8       MF
# 8              ARG  argentina (ARG)       1009         9       FW
# 9              ARG  argentina (ARG)       1010        10       FW
#
#           Player_Name Date_Of_Birth  Age  Caps  Goals          Current_Club  \
# 0       Franco Armani    1986-10-16   36    18      0           River Plate
# 1          Juan Foyth    1998-01-12   24    16      0            Villarreal
# 2  Nicolás Tagliafico    1992-08-31   30    42      0                  Lyon
# 3     Gonzalo Montiel    1997-01-01   25    18      0               Sevilla
# 4     Leandro Paredes    1994-06-29   28    46      4              Juventus
# 5     Germán Pezzella    1991-06-27   31    32      2            Real Betis
# 6     Rodrigo De Paul    1994-05-24   28    44      2       Atlético Madrid
# 7        Marcos Acuña    1991-10-28   31    43      0               Sevilla
# 8      Julián Álvarez    2000-01-31   22    12      3       Manchester City
# 9        Lionel Messi    1987-06-24   35   165     91   Paris Saint-Germain
#
#                Football_League         FA
# 0  Liga Professional Argentina  Argentina
# 1                      La Liga      Spain
# 2                      Ligue 1     France
# 3                      La Liga      Spain
# 4                      Serie A      Italy
# 5                      La Liga      Spain
# 6                      La Liga      Spain
# 7                      La Liga      Spain
# 8               Premier League    England
# 9                      Ligue 1     France

# %% [markdown]
# ### Remove everything past the ')' after the National_Team

# %%
df_World_Cup['National_Team'] = df_World_Cup['National_Team'].str.split(')').str[0] + ")" 
df_World_Cup
# Out:
#     National_Team_ID    National_Team  Player_No  Squad_No Position  \
# 0                ARG  argentina (ARG)       1001         1       GK
# 1                ARG  argentina (ARG)       1002         2       DF
# 2                ARG  argentina (ARG)       1003         3       DF
# 3                ARG  argentina (ARG)       1004         4       DF
# 4                ARG  argentina (ARG)       1005         5       MF
# ..               ...              ...        ...       ...      ...
# 825              WAL      wales (WAL)       1826        22       MF
# 826              WAL      wales (WAL)       1827        23       MF
# 827              WAL      wales (WAL)       1828        24       DF
# 828              WAL      wales (WAL)       1829        25       MF
# 829              WAL      wales (WAL)       1830        26       MF
#
#             Player_Name Date_Of_Birth  Age  Caps  Goals         Current_Club  \
# 0         Franco Armani    1986-10-16   36    18      0          River Plate
# 1            Juan Foyth    1998-01-12   24    16      0           Villarreal
# 2    Nicolás Tagliafico    1992-08-31   30    42      0                 Lyon
# 3       Gonzalo Montiel    1997-01-01   25    18      0              Sevilla
# 4       Leandro Paredes    1994-06-29   28    46      4             Juventus
# ..                  ...           ...  ...   ...    ...                  ...
# 825        Sorba Thomas    1999-01-25   23     6      0    Huddersfield Town
# 826        Dylan Levitt    2000-11-17   22    13      0        Dundee United
# 827         Ben Cabango    2000-05-30   22     5      0         Swansea City
# 828       Rubin Colwill    2002-04-27   20     7      1         Cardiff City
# 829       Matthew Smith    1999-11-22   22    19      0   Milton Keynes Dons
#
#                  Football_League         FA
# 0    Liga Professional Argentina  Argentina
# 1                        La Liga      Spain
# 2                        Ligue 1     France
# 3                        La Liga      Spain
# 4                        Serie A      Italy
# ..                           ...        ...
# 825                 Championship    England
# 826                  Premiership   Scotland
# 827                 Championship    England
# 828                 Championship    England
# 829                   League One    England
#
# [830 rows x 13 columns]

# %% [markdown]
# ### Separate the Country Name from the Country Code.

# %%
df_World_Cup[['National_Team','Code']] = df_World_Cup['National_Team'].str.split('(', 1, expand=True) 
df_World_Cup
# Out:
#     National_Team_ID National_Team  Player_No  Squad_No Position  \
# 0                ARG    argentina        1001         1       GK
# 1                ARG    argentina        1002         2       DF
# 2                ARG    argentina        1003         3       DF
# 3                ARG    argentina        1004         4       DF
# 4                ARG    argentina        1005         5       MF
# ..               ...           ...        ...       ...      ...
# 825              WAL        wales        1826        22       MF
# 826              WAL        wales        1827        23       MF
# 827              WAL        wales        1828        24       DF
# 828              WAL        wales        1829        25       MF
# 829              WAL        wales        1830        26       MF
#
#             Player_Name Date_Of_Birth  Age  Caps  Goals         Current_Club  \
# 0         Franco Armani    1986-10-16   36    18      0          River Plate
# 1            Juan Foyth    1998-01-12   24    16      0           Villarreal
# 2    Nicolás Tagliafico    1992-08-31   30    42      0                 Lyon
# 3       Gonzalo Montiel    1997-01-01   25    18      0              Sevilla
# 4       Leandro Paredes    1994-06-29   28    46      4             Juventus
# ..                  ...           ...  ...   ...    ...                  ...
# 825        Sorba Thomas    1999-01-25   23     6      0    Huddersfield Town
# 826        Dylan Levitt    2000-11-17   22    13      0        Dundee United
# 827         Ben Cabango    2000-05-30   22     5      0         Swansea City
# 828       Rubin Colwill    2002-04-27   20     7      1         Cardiff City
# 829       Matthew Smith    1999-11-22   22    19      0   Milton Keynes Dons
#
#                  Football_League         FA  Code
# 0    Liga Professional Argentina  Argentina  ARG)
# 1                        La Liga      Spain  ARG)
# 2                        Ligue 1     France  ARG)
# 3                        La Liga      Spain  ARG)
# 4                        Serie A      Italy  ARG)
# ..                           ...        ...   ...
# 825                 Championship    England  WAL)
# 826                  Premiership   Scotland  WAL)
# 827                 Championship    England  WAL)
# 828                 Championship    England  WAL)
# 829                   League One    England  WAL)
#
# [830 rows x 14 columns]

# %% [markdown]
# ### Set the Column order

# %%
df_World_Cup = df_World_Cup.reindex(columns=['National_Team_ID','National_Team', 'Code','Player_No','Squad_No', 'Position', 'Player_Name', 'Date_Of_Birth', 'Age', 'Caps', 'Goals', 'Current_Club', 'Football_League', 'FA'])
df_World_Cup
# Out:
#     National_Team_ID National_Team  Code  Player_No  Squad_No Position  \
# 0                ARG    argentina   ARG)       1001         1       GK
# 1                ARG    argentina   ARG)       1002         2       DF
# 2                ARG    argentina   ARG)       1003         3       DF
# 3                ARG    argentina   ARG)       1004         4       DF
# 4                ARG    argentina   ARG)       1005         5       MF
# ..               ...           ...   ...        ...       ...      ...
# 825              WAL        wales   WAL)       1826        22       MF
# 826              WAL        wales   WAL)       1827        23       MF
# 827              WAL        wales   WAL)       1828        24       DF
# 828              WAL        wales   WAL)       1829        25       MF
# 829              WAL        wales   WAL)       1830        26       MF
#
#             Player_Name Date_Of_Birth  Age  Caps  Goals         Current_Club  \
# 0         Franco Armani    1986-10-16   36    18      0          River Plate
# 1            Juan Foyth    1998-01-12   24    16      0           Villarreal
# 2    Nicolás Tagliafico    1992-08-31   30    42      0                 Lyon
# 3       Gonzalo Montiel    1997-01-01   25    18      0              Sevilla
# 4       Leandro Paredes    1994-06-29   28    46      4             Juventus
# ..                  ...           ...  ...   ...    ...                  ...
# 825        Sorba Thomas    1999-01-25   23     6      0    Huddersfield Town
# 826        Dylan Levitt    2000-11-17   22    13      0        Dundee United
# 827         Ben Cabango    2000-05-30   22     5      0         Swansea City
# 828       Rubin Colwill    2002-04-27   20     7      1         Cardiff City
# 829       Matthew Smith    1999-11-22   22    19      0   Milton Keynes Dons
#
#                  Football_League         FA
# 0    Liga Professional Argentina  Argentina
# 1                        La Liga      Spain
# 2                        Ligue 1     France
# 3                        La Liga      Spain
# 4                        Serie A      Italy
# ..                           ...        ...
# 825                 Championship    England
# 826                  Premiership   Scotland
# 827                 Championship    England
# 828                 Championship    England
# 829                   League One    England
#
# [830 rows x 14 columns]

# %% [markdown]
# ### set column - Player_No as the primary key index

# %%
df_World_Cup.set_index("Player_No")
# Out:
#           National_Team_ID National_Team  Code  Squad_No Position  \
# Player_No
# 1001                   ARG    argentina   ARG)         1       GK
# 1002                   ARG    argentina   ARG)         2       DF
# 1003                   ARG    argentina   ARG)         3       DF
# 1004                   ARG    argentina   ARG)         4       DF
# 1005                   ARG    argentina   ARG)         5       MF
# ...                    ...           ...   ...       ...      ...
# 1826                   WAL        wales   WAL)        22       MF
# 1827                   WAL        wales   WAL)        23       MF
# 1828                   WAL        wales   WAL)        24       DF
# 1829                   WAL        wales   WAL)        25       MF
# 1830                   WAL        wales   WAL)        26       MF
#
#                   Player_Name Date_Of_Birth  Age  Caps  Goals  \
# Player_No
# 1001            Franco Armani    1986-10-16   36    18      0
# 1002               Juan Foyth    1998-01-12   24    16      0
# 1003       Nicolás Tagliafico    1992-08-31   30    42      0
# 1004          Gonzalo Montiel    1997-01-01   25    18      0
# 1005          Leandro Paredes    1994-06-29   28    46      4
# ...                       ...           ...  ...   ...    ...
# 1826             Sorba Thomas    1999-01-25   23     6      0
# 1827             Dylan Levitt    2000-11-17   22    13      0
# 1828              Ben Cabango    2000-05-30   22     5      0
# 1829            Rubin Colwill    2002-04-27   20     7      1
# 1830            Matthew Smith    1999-11-22   22    19      0
#
#                   Current_Club              Football_League         FA
# Player_No
# 1001               River Plate  Liga Professional Argentina  Argentina
# 1002                Villarreal                      La Liga      Spain
# 1003                      Lyon                      Ligue 1     France
# 1004                   Sevilla                      La Liga      Spain
# 1005                  Juventus                      Serie A      Italy
# ...                        ...                          ...        ...
# 1826         Huddersfield Town                 Championship    England
# 1827             Dundee United                  Premiership   Scotland
# 1828              Swansea City                 Championship    England
# 1829              Cardiff City                 Championship    England
# 1830        Milton Keynes Dons                   League One    England
#
# [830 rows x 13 columns]

# %% [markdown]
# ### Drop the Code column, not required as i already have National_Team_ID

# %%
df_World_Cup = df_World_Cup.drop('Code', axis = 1)

# %% [markdown]
# ### Create clean up function to clean National_Team Column and apply on next step

# %%
def cleanup(name): 
    name = name.strip()
    name = name.capitalize()
    return name

# %%
df_World_Cup['National_Team'] = df_World_Cup['National_Team'].apply(cleanup)

# %% [markdown]
# ## Run data now on Player Experience

# %% [markdown]
# ### Find mean and Standard Deviation of Player Caps to run function below

# %%
df_World_Cup['Caps'].dropna().describe()
# Out:
# count    830.000000
# mean      34.366265
# std       33.971368
# min        0.000000
# 25%        8.000000
# 50%       24.000000
# 75%       47.750000
# max      191.000000
# Name: Caps, dtype: float64

# %%
def Experience(Caps): # create a function and if statement to find experience of Players
    if Caps < 20:
        return 'Newcomer'
    elif Caps >= 20 and Caps < 40:
        return 'Novice'
    elif Caps >= 40 and Caps < 80:
        return 'Regular'
    elif Caps >= 80 and Caps < 101:
        return 'Master'
    else:
        return 'Legend'

# %% [markdown]
# Apply the Experience column to the DataFrame, based on above Function and If Statement

# %%
df_World_Cup['Experience'] = df_World_Cup['Caps'].apply(Experience)

# %% [markdown]
# Create a mini DataFrame to review Player Data

# %%
Player_Review = df_World_Cup[ ['Player_Name','Caps', 'National_Team','Experience','Age'] ]

# %%
Player_Review
# Out:
#             Player_Name  Caps National_Team Experience  Age
# 0         Franco Armani    18     Argentina   Newcomer   36
# 1            Juan Foyth    16     Argentina   Newcomer   24
# 2    Nicolás Tagliafico    42     Argentina    Regular   30
# 3       Gonzalo Montiel    18     Argentina   Newcomer   25
# 4       Leandro Paredes    46     Argentina    Regular   28
# ..                  ...   ...           ...        ...  ...
# 825        Sorba Thomas     6         Wales   Newcomer   23
# 826        Dylan Levitt    13         Wales   Newcomer   22
# 827         Ben Cabango     5         Wales   Newcomer   22
# 828       Rubin Colwill     7         Wales   Newcomer   20
# 829       Matthew Smith    19         Wales   Newcomer   22
#
# [830 rows x 5 columns]

# %%
ExperienceData = df_World_Cup.groupby('Experience')['Experience'].count()
ExperienceData
# Out:
# Experience
# Legend       53
# Master       32
# Newcomer    363
# Novice      198
# Regular     184
# Name: Experience, dtype: int64

# %% [markdown]
# Show Cap experience, by category, on Graph

# %%
ExperienceData.plot(x="Experience", y=["Caps"], kind="bar")
# Out:
# <AxesSubplot:xlabel='Experience'>

# %% [markdown]
# Show Top 20 Players By Caps

# %%
df_World_Cup.sort_values('Caps', ascending = False).head(20)
# Out:
#     National_Team_ID National_Team  Player_No  Squad_No Position  \
# 603              POR      Portugal       1552         7       FW
# 536              MEX        Mexico       1459        18       MF
# 632              QAT         Qatar       1581        10       MF
# 9                ARG     Argentina       1010        10       FW
# 754              URU       Uruguay       1755         3       DF
# 191              CRO       Croatia       1192        10       MF
# 160              CRC    Costa rica       1161         5       MF
# 165              CRC    Costa rica       1166        10       MF
# 56               BEL       Belgium       1057         5       DF
# 312              FRA        France       1287         1       GK
# 290              ESP         Spain       1679         5       MF
# 419              JPN         Japan       1394         5       DF
# 579              POL        Poland       1528         9       FW
# 760              URU       Uruguay       1761         9       FW
# 772              URU       Uruguay       1773        21       FW
# 752              URU       Uruguay       1753         1       GK
# 531              MEX        Mexico       1454        13       GK
# 625              QAT         Qatar       1574         3       MF
# 599              POR      Portugal       1548         3       DF
# 533              MEX        Mexico       1456        15       DF
#
#              Player_Name Date_Of_Birth  Age  Caps  Goals  \
# 603   Cristiano Ronaldo     1985-02-05   37   191    117
# 536     Andrés Guardado     1986-09-28   36   178     28
# 632     Hassan Al-Haydos    1990-12-11   31   169     36
# 9           Lionel Messi    1987-06-24   35   165     91
# 754         Diego Godín     1986-02-16   36   159      8
# 191         Luka Modrić     1985-09-09   37   155     23
# 160         Celso Borges    1988-05-27   34   155     27
# 165          Bryan Ruiz     1985-08-18   37   146     29
# 56        Jan Vertonghen    1987-04-24   35   142      9
# 312         Hugo Lloris     1986-12-26   35   139      0
# 290     Sergio Busquets     1988-07-16   34   139      2
# 419        Yuto Nagatomo    1986-09-12   36   138      4
# 579  Robert Lewandowski     1988-08-21   34   134     76
# 760          Luis Suárez    1987-01-24   35   134     68
# 772       Edinson Cavani    1987-02-14   35   133     58
# 752     Fernando Muslera    1986-06-16   36   133      0
# 531      Guillermo Ochoa    1985-07-13   37   131      0
# 625    Abdelkarim Hassan    1993-08-28   29   130     15
# 599                 Pepe    1983-02-26   39   129      7
# 533        Héctor Moreno    1988-01-17   34   128      5
#
#              Current_Club              Football_League          FA Experience
# 603     Manchester United               Premier League     England     Legend
# 536            Real Betis                      La Liga       Spain     Legend
# 632               Al-Sadd                 Stars League       Qatar     Legend
# 9     Paris Saint-Germain                      Ligue 1      France     Legend
# 754       Vélez Sarsfield  Liga Professional Argentina   Argentina     Legend
# 191           Real Madrid                      La Liga       Spain     Legend
# 160           Alajuelense             Primera Division  Costa Rica     Legend
# 165           Alajuelense             Primera Division  Costa Rica     Legend
# 56             Anderlecht             First Division A     Belgium     Legend
# 312     Tottenham Hotspur               Premier League     England     Legend
# 290             Barcelona                      La Liga       Spain     Legend
# 419              FC Tokyo                    J1 League       Japan     Legend
# 579             Barcelona                      La Liga       Spain     Legend
# 760              Nacional   Primera Division - Uruguay     Uruguay     Legend
# 772              Valencia                      La Liga       Spain     Legend
# 752           Galatasaray                    Super Lig      Turkey     Legend
# 531               América                      Liga MX      Mexico     Legend
# 625               Al-Sadd                 Stars League       Qatar     Legend
# 599                 Porto                Primeira Liga    Portugal     Legend
# 533             Monterrey                      Liga MX      Mexico     Legend

# %% [markdown]
# ### Whats the maximum caps by player, prior to World Cup

# %%
df_World_Cup['Caps'].max()
# Out:
# 191

# %% [markdown]
# ### Find data on most capped player

# %%
df_World_Cup.iloc[ df_World_Cup['Caps'].idxmax() ]
# Out:
# National_Team_ID                    POR
# National_Team                  Portugal
# Player_No                          1552
# Squad_No                              7
# Position                             FW
# Player_Name          Cristiano Ronaldo
# Date_Of_Birth       1985-02-05 00:00:00
# Age                                  37
# Caps                                191
# Goals                               117
# Current_Club          Manchester United
# Football_League          Premier League
# FA                              England
# Experience                       Legend
# Name: 603, dtype: object

# %% [markdown]
# ## Run data now on Player Age info

# %% [markdown]
# ### Find mean and Standard Deviation of Player Age

# %%
df_World_Cup['Age'].dropna().describe()
# Out:
# count    830.000000
# mean      26.951807
# std        4.270988
# min       18.000000
# 25%       24.000000
# 50%       27.000000
# 75%       30.000000
# max       40.000000
# Name: Age, dtype: float64

# %% [markdown]
# Create a function and if statement to find Age Range of Players

# %%
def AgeRange(Age): 
    if Age < 18:
        return 'Under 18'
    elif Age >= 18 and Age <= 21:
        return '18-21'
    elif Age > 21 and Age <= 25:
        return '22-25'
    elif Age > 25 and Age <= 29:
        return '26-29'
    elif Age > 29 and Age <= 33:
        return '30-33'
    elif Age > 33 and Age <= 37:
        return '34-37'
    elif Age > 38 and Age <= 41:
        return '38-41'
    else:
        return 'Over 41'

# %% [markdown]
# ### Apply the AgeRange column to the DataFrame, based on above Function and If Statement

# %%
df_World_Cup['Age Range'] = df_World_Cup['Age'].apply(AgeRange)

# %% [markdown]
# ### Create a mini DataFrame to review Players by Age

# %%
Player_Age_Range = df_World_Cup[ ['Player_No','Player_Name', 'Date_Of_Birth','Age','Caps','Age Range','FA','Current_Club'] ] 
Player_Age_Range
# Out:
#      Player_No         Player_Name Date_Of_Birth  Age  Caps Age Range  \
# 0         1001       Franco Armani    1986-10-16   36    18     34-37
# 1         1002          Juan Foyth    1998-01-12   24    16     22-25
# 2         1003  Nicolás Tagliafico    1992-08-31   30    42     30-33
# 3         1004     Gonzalo Montiel    1997-01-01   25    18     22-25
# 4         1005     Leandro Paredes    1994-06-29   28    46     26-29
# ..         ...                 ...           ...  ...   ...       ...
# 825       1826        Sorba Thomas    1999-01-25   23     6     22-25
# 826       1827        Dylan Levitt    2000-11-17   22    13     22-25
# 827       1828         Ben Cabango    2000-05-30   22     5     22-25
# 828       1829       Rubin Colwill    2002-04-27   20     7     18-21
# 829       1830       Matthew Smith    1999-11-22   22    19     22-25
#
#             FA         Current_Club
# 0    Argentina          River Plate
# 1        Spain           Villarreal
# 2       France                 Lyon
# 3        Spain              Sevilla
# 4        Italy             Juventus
# ..         ...                  ...
# 825    England    Huddersfield Town
# 826   Scotland        Dundee United
# 827    England         Swansea City
# 828    England         Cardiff City
# 829    England   Milton Keynes Dons
#
# [830 rows x 8 columns]

# %% [markdown]
# ### Group the data by Age Range and count per category

# %%
AgeData = Player_Age_Range.groupby('Age Range')['Age Range'].count() 
AgeData
# Out:
# Age Range
# 18-21       80
# 22-25      262
# 26-29      248
# 30-33      182
# 34-37       50
# 38-41        6
# Over 41      2
# Name: Age Range, dtype: int64

# %% [markdown]
# ### show Age Range, by category, on Graph

# %%
AgeData.plot(x="Age Range", y=["Age"], kind="bar")
# Out:
# <AxesSubplot:xlabel='Age Range'>

# %% [markdown]
# ### What's the maximum Player Age

# %%
Player_Age_Range['Age'].max()
# Out:
# 40

# %% [markdown]
# ### Find data on oldest player

# %%
Player_Age_Range.iloc[ Player_Age_Range['Age'].idxmax() ]
# Out:
# Player_No                       1442
# Player_Name         Alfredo Talavera
# Date_Of_Birth    1982-09-18 00:00:00
# Age                               40
# Caps                              40
# Age Range                      38-41
# FA                            Mexico
# Current_Club                  Juárez
# Name: 519, dtype: object

# %% [markdown]
# ### Breakdown Year of Birth, count,sort and plot on a graph

# %%
Year = Player_Age_Range.Date_Of_Birth.dt.year.value_counts().sort_index()

# %%
Year.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Create Goal Data on Players with more than 19 caps to find the Top Goal Scorers among the more experience Players, for more balanced data

# %% [markdown]
# ### Create a column to find Ratio of goals scored by player to Games played (Caps)

# %%
df_World_Cup['Goals_Per_Game'] = df_World_Cup['Goals'] / df_World_Cup['Caps']

# %% [markdown]
# Create a mini DataFrame to review Players by Age

# %%
Goal_Data = df_World_Cup[ ['Player_Name','National_Team','Position','Age','Caps','Goals','Goals_Per_Game','Current_Club'] ]

# %% [markdown]
# ### Find the player with the best Goal to Cap ratio, with 20 or more caps to date

# %%
Top_Scorer = Goal_Data['Caps'] > 19

# %% [markdown]
# ### Find the Top 10 more experience players by Goals Scored Ratio

# %%
Goal_Data[Top_Scorer].sort_values('Goals_Per_Game', ascending = False).head(10)
# Out:
#              Player_Name National_Team Position  Age  Caps  Goals  \
# 268          Harry Kane        England       FW   29    75     51
# 60         Romelu Lukaku       Belgium       FW   29   102     68
# 682  Aleksandar Mitrović        Serbia       FW   28    76     50
# 409        Sardar Azmoun          Iran       FW   27    65     41
# 123       Jonathan David        Canada       FW   22    35     22
# 87                Neymar        Brasil       FW   30   121     75
# 603   Cristiano Ronaldo       Portugal       FW   37   191    117
# 579  Robert Lewandowski         Poland       FW   34   134     76
# 347         Serge Gnabry       Germany       FW   27    36     20
# 9           Lionel Messi     Argentina       FW   35   165     91
#
#      Goals_Per_Game          Current_Club
# 268        0.680000     Tottenham Hotspur
# 60         0.666667        Internazionale
# 682        0.657895                Fulham
# 409        0.630769      Bayer Leverkusen
# 123        0.628571                 Lille
# 87         0.619835   Paris Saint-Germain
# 603        0.612565     Manchester United
# 579        0.567164             Barcelona
# 347        0.555556         Bayern Munich
# 9          0.551515   Paris Saint-Germain

# %% [markdown]
# ## Review Data by Leagues - please note that Football League, FA and FIFA Region are in respect of the Football Club, Not the Players National Team

# %% [markdown]
# ### Create a mini DataFrame to review Club Data

# %%
League_Review = df_World_Cup[ ['Player_No','Player_Name','Current_Club','Football_League','FA'] ]

# %%
League_Review
# Out:
#      Player_No         Player_Name         Current_Club  \
# 0         1001       Franco Armani          River Plate
# 1         1002          Juan Foyth           Villarreal
# 2         1003  Nicolás Tagliafico                 Lyon
# 3         1004     Gonzalo Montiel              Sevilla
# 4         1005     Leandro Paredes             Juventus
# ..         ...                 ...                  ...
# 825       1826        Sorba Thomas    Huddersfield Town
# 826       1827        Dylan Levitt        Dundee United
# 827       1828         Ben Cabango         Swansea City
# 828       1829       Rubin Colwill         Cardiff City
# 829       1830       Matthew Smith   Milton Keynes Dons
#
#                  Football_League         FA
# 0    Liga Professional Argentina  Argentina
# 1                        La Liga      Spain
# 2                        Ligue 1     France
# 3                        La Liga      Spain
# 4                        Serie A      Italy
# ..                           ...        ...
# 825                 Championship    England
# 826                  Premiership   Scotland
# 827                 Championship    England
# 828                 Championship    England
# 829                   League One    England
#
# [830 rows x 5 columns]

# %% [markdown]
# ### Set column as primary key index

# %%
League_Review.set_index("Player_No")
# Out:
#                   Player_Name         Current_Club  \
# Player_No
# 1001            Franco Armani          River Plate
# 1002               Juan Foyth           Villarreal
# 1003       Nicolás Tagliafico                 Lyon
# 1004          Gonzalo Montiel              Sevilla
# 1005          Leandro Paredes             Juventus
# ...                       ...                  ...
# 1826             Sorba Thomas    Huddersfield Town
# 1827             Dylan Levitt        Dundee United
# 1828              Ben Cabango         Swansea City
# 1829            Rubin Colwill         Cardiff City
# 1830            Matthew Smith   Milton Keynes Dons
#
#                        Football_League         FA
# Player_No
# 1001       Liga Professional Argentina  Argentina
# 1002                           La Liga      Spain
# 1003                           Ligue 1     France
# 1004                           La Liga      Spain
# 1005                           Serie A      Italy
# ...                                ...        ...
# 1826                      Championship    England
# 1827                       Premiership   Scotland
# 1828                      Championship    England
# 1829                      Championship    England
# 1830                        League One    England
#
# [830 rows x 4 columns]

# %% [markdown]
# ### Find the Top 20 Football Clubs with the most assigned Players to the World Cup - also list their League and FA

# %%
Top_Clubs = League_Review.groupby(['Current_Club','Football_League','FA'])['Current_Club'].count()
Top_Clubs.sort_values(axis=0, ascending = False).head(20)
# Out:
# Current_Club             Football_League   FA
#  Barcelona               La Liga           Spain           17
#  Manchester City         Premier League    England         16
#  Bayern Munich           Bundesliga        Germany         16
#  Al-Sadd                 Stars League      Qatar           15
#  Manchester United       Premier League    England         14
#  Real Madrid             La Liga           Spain           13
#  Al-Hilal                Saudi Division 1  Saudi Arabia    12
#  Chelsea                 Premier League    England         12
#  Atlético Madrid         La Liga           Spain           12
#  Borussia Dortmund       Bundesliga        Germany         11
#  Paris Saint-Germain     Ligue 1           France          11
#  Ajax                    Eredivisie        Netherlands     11
#  Tottenham Hotspur       Premier League    England         11
#  Juventus                Serie A           Italy           11
#  Arsenal                 Premier League    England         10
#  Sevilla                 La Liga           Spain           10
#  Rennes                  Ligue 1           France           8
#  Brighton & Hove Albion  Premier League    England          8
#  Club Brugge             First Division A  Belgium          8
#  Leicester City          Premier League    England          7
# Name: Current_Club, dtype: int64

# %%
Top_Clubs.mean()
# Out:
# 2.804054054054054

# %%
Top_Clubs.median()
# Out:
# 2.0

# %%
Top_Clubs.std()
# Out:
# 2.9219422001122943

# %% [markdown]
# ### Find the Top 10 Football Leagues with the most assigned Players to the World Cup - also list their FA

# %%
Top_Leagues = League_Review.groupby(['Football_League','FA'])['Football_League'].count() 
Top_Leagues.sort_values(axis=0, ascending = False).head(10)
# Out:
# Football_League   FA
# Premier League    England         134
# La Liga           Spain            84
# Bundesliga        Germany          77
# Serie A           Italy            65
# Ligue 1           France           55
# MLS               USA              36
# Saudi Division 1  Saudi Arabia     35
# Stars League      Qatar            33
# Championship      England          26
# Liga MX           Mexico           24
# Name: Football_League, dtype: int64

# %%
Top_Leagues.mean()
# Out:
# 15.660377358490566

# %%
Top_Leagues.median()
# Out:
# 6.0

# %%
Top_Leagues.std()
# Out:
# 25.238053835296487

# %% [markdown]
# ## Call in outcome table to merge data

# %% [markdown]
# ### Call in a new Data Frame based on World Cup Outcome by Nation

# %%
df_Outcome = pd.read_csv('C:\\Users\\Ciaran Lynch\\Outcome.csv', header=None)

# %%
Column_Outcome =  {
                    df_Outcome.columns[0]:  'National_Team_ID',
                    df_Outcome.columns[1]:  'National_Team',
                    df_Outcome.columns[2]:  'Final_Outcome'
                                      
                  }


df_Outcome.rename(columns = Column_Outcome, inplace = True) # adding a dictionary to place columns into the headers of Outcome csv

# %% [markdown]
# ### Set column - National_Team_ID as the primary key index

# %%
df_Outcome.set_index('National_Team_ID') 
df_Outcome
# Out:
#    National_Team_ID National_Team   Final_Outcome
# 0               ARG     Argentina          Winner
# 1               AUS     Australia         Last 16
# 2               BEL       Belgium    Group Stages
# 3               BRA        Brasil  Quarter Finals
# 4               CAN        Canada    Group Stages
# 5               CMR      Cameroon    Group Stages
# 6               CRC    Costa Rica    Group Stages
# 7               CRO       Croatia           Third
# 8               DEN       Denmark    Group Stages
# 9               ECU       Ecuador    Group Stages
# 10              ENG       England  Quarter Finals
# 11              ESP         Spain         Last 16
# 12              FRA        France       Runner Up
# 13              GER       Germany    Group Stages
# 14              GHA         Ghana    Group Stages
# 15              IRN          Iran    Group Stages
# 16              JPN         Japan         Last 16
# 17              KOR     Korea Rep         Last 16
# 18              KSA  Saudi Arabia    Group Stages
# 19              MAR       Morocco          Fourth
# 20              MEX        Mexico    Group Stages
# 21              NED   Netherlands  Quarter Finals
# 22              POL        Poland         Last 16
# 23              POR      Portugal  Quarter Finals
# 24              QAT         Qatar    Group Stages
# 25              SEN       Senegal         Last 16
# 26              SRB        Serbia    Group Stages
# 27              SUI   Switzerland         Last 16
# 28              TUN       Tunisia    Group Stages
# 29              URU       Uruguay    Group Stages
# 30              USA           USA         Last 16
# 31              WAL         Wales    Group Stages

# %%
df_Outcome.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   National_Team_ID  32 non-null     object
#  1   National_Team     32 non-null     object
#  2   Final_Outcome     32 non-null     object
# dtypes: object(3)
# memory usage: 896.0+ bytes

# %%
result = pd.merge(df_Outcome,df_World_Cup, left_on='National_Team_ID', right_on = 'National_Team_ID')

# %%
result.columns
# Out:
# Index(['National_Team_ID', 'National_Team_x', 'Final_Outcome',
#        'National_Team_y', 'Player_No', 'Squad_No', 'Position', 'Player_Name',
#        'Date_Of_Birth', 'Age', 'Caps', 'Goals', 'Current_Club',
#        'Football_League', 'FA', 'Experience', 'Age Range', 'Goals_Per_Game'],
#       dtype='object')

# %%
result.shape
# Out:
# (830, 18)

# %%
result = result.drop('National_Team_y',axis = 1)

# %%
result = result.drop('Date_Of_Birth',axis = 1)

# %%
result = result.drop('FA',axis = 1)

# %%
result = result.drop('Goals_Per_Game',axis = 1)

# %%
result.rename(columns={'National_Team_x': 'National_Team','Final_Outcome_x' : 'Final_Outcome' }, inplace=True)

# %%
result
# Out:
#     National_Team_ID National_Team Final_Outcome  Player_No  Squad_No  \
# 0                ARG     Argentina        Winner       1001         1
# 1                ARG     Argentina        Winner       1002         2
# 2                ARG     Argentina        Winner       1003         3
# 3                ARG     Argentina        Winner       1004         4
# 4                ARG     Argentina        Winner       1005         5
# ..               ...           ...           ...        ...       ...
# 825              WAL         Wales  Group Stages       1826        22
# 826              WAL         Wales  Group Stages       1827        23
# 827              WAL         Wales  Group Stages       1828        24
# 828              WAL         Wales  Group Stages       1829        25
# 829              WAL         Wales  Group Stages       1830        26
#
#     Position         Player_Name  Age  Caps  Goals         Current_Club  \
# 0         GK       Franco Armani   36    18      0          River Plate
# 1         DF          Juan Foyth   24    16      0           Villarreal
# 2         DF  Nicolás Tagliafico   30    42      0                 Lyon
# 3         DF     Gonzalo Montiel   25    18      0              Sevilla
# 4         MF     Leandro Paredes   28    46      4             Juventus
# ..       ...                 ...  ...   ...    ...                  ...
# 825       MF        Sorba Thomas   23     6      0    Huddersfield Town
# 826       MF        Dylan Levitt   22    13      0        Dundee United
# 827       DF         Ben Cabango   22     5      0         Swansea City
# 828       MF       Rubin Colwill   20     7      1         Cardiff City
# 829       MF       Matthew Smith   22    19      0   Milton Keynes Dons
#
#                  Football_League Experience Age Range
# 0    Liga Professional Argentina   Newcomer     34-37
# 1                        La Liga   Newcomer     22-25
# 2                        Ligue 1    Regular     30-33
# 3                        La Liga   Newcomer     22-25
# 4                        Serie A    Regular     26-29
# ..                           ...        ...       ...
# 825                 Championship   Newcomer     22-25
# 826                  Premiership   Newcomer     22-25
# 827                 Championship   Newcomer     22-25
# 828                 Championship   Newcomer     18-21
# 829                   League One   Newcomer     22-25
#
# [830 rows x 14 columns]

# %% [markdown]
# ## Get the list of players from the Teams that qualified for the Semi Final or better (last 4 left in the Tournament - Should be 104 players)

# %% [markdown]
# ### Then compare the age and cap data with the original 830 Players

# %%
df_Last_Four = result[ (result.Final_Outcome == 'Winner') | (result.Final_Outcome == 'Runner Up') | (result.Final_Outcome == 'Third') | (result.Final_Outcome == 'Fourth')]

# %%
df_Last_Four
# Out:
#     National_Team_ID National_Team Final_Outcome  Player_No  Squad_No  \
# 0                ARG     Argentina        Winner       1001         1
# 1                ARG     Argentina        Winner       1002         2
# 2                ARG     Argentina        Winner       1003         3
# 3                ARG     Argentina        Winner       1004         4
# 4                ARG     Argentina        Winner       1005         5
# ..               ...           ...           ...        ...       ...
# 514              MAR       Morocco        Fourth       1489        22
# 515              MAR       Morocco        Fourth       1490        23
# 516              MAR       Morocco        Fourth       1491        24
# 517              MAR       Morocco        Fourth       1492        25
# 518              MAR       Morocco        Fourth       1493        26
#
#     Position           Player_Name  Age  Caps  Goals  Current_Club  \
# 0         GK         Franco Armani   36    18      0   River Plate
# 1         DF            Juan Foyth   24    16      0    Villarreal
# 2         DF    Nicolás Tagliafico   30    42      0          Lyon
# 3         DF       Gonzalo Montiel   25    18      0       Sevilla
# 4         MF       Leandro Paredes   28    46      4      Juventus
# ..       ...                   ...  ...   ...    ...           ...
# 514       GK  Ahmed Reda Tagnaouti   26     3      0      Wydad AC
# 515       MF     Bilal El Khannous   18     0      0          Genk
# 516       DF           Badr Benoun   29     3      0      Qatar SC
# 517       DF   Yahia Attiyat Allah   27     2      0      Wydad AC
# 518       MF         Yahya Jabrane   31     5      0      Wydad AC
#
#                  Football_League Experience Age Range
# 0    Liga Professional Argentina   Newcomer     34-37
# 1                        La Liga   Newcomer     22-25
# 2                        Ligue 1    Regular     30-33
# 3                        La Liga   Newcomer     22-25
# 4                        Serie A    Regular     26-29
# ..                           ...        ...       ...
# 514                   Botola Pro   Newcomer     26-29
# 515             First Division A   Newcomer     18-21
# 516                 Stars League   Newcomer     26-29
# 517                   Botola Pro   Newcomer     26-29
# 518                   Botola Pro   Newcomer     30-33
#
# [104 rows x 14 columns]

# %%
df_World_Cup['Caps'].mean()
# Out:
# 34.36626506024096

# %%
df_World_Cup['Caps'].median()
# Out:
# 24.0

# %%
df_World_Cup['Age'].mean()
# Out:
# 26.951807228915662

# %%
df_Last_Four['Caps'].mean()
# Out:
# 31.528846153846153

# %%
df_Last_Four['Caps'].median()
# Out:
# 18.0

# %%
df_Last_Four['Age'].mean()
# Out:
# 26.971153846153847

# %% [markdown]
# # Conclusion
#
# This analysis provides insights into:
#
# - Player experience distribution
# - Age structure of the tournament
# - Top goal scorers by efficiency
# - Clubs and leagues most affected
# - Differences between all players and the last four teams
#
# The project demonstrates a full data pipeline: sourcing, cleaning, transforming, analysing, and visualising real‑world football data.
